# %% [markdown]
# # [1차시] 데이터 탐색과 기초 통계 입문
# ---
# ## 1. 학습 목표
# * Pandas와 NumPy 라이브러리를 이해하고 호출할 수 있다.
# * 데이터셋을 불러와 구조를 파악하고 기초 통계를 확인할 수 있다.
# * 데이터 내의 결측치(Missing Value)를 찾아낼 수 있다.

# %% [markdown]
# ### 1-1. 라이브러리 불러오기

# %%
import pandas as pd
import numpy as np
import seaborn as sns

print("라이브러리 로드 완료!")

# %% [markdown]
# ### 1-2. 데이터셋 불러오기 (타이타닉 데이터)
# 분석에 가장 널리 쓰이는 타이타닉 생존자 데이터를 사용해 봅시다.

# %%
# seaborn 라이브러리에서 제공하는 타이타닉 데이터를 불러옵니다.
df = sns.load_dataset('titanic')

# 데이터의 상위 5행을 확인합니다.
df.head()

# %% [markdown]
# ### 1-3. 데이터 구조 파악하기
# 데이터가 어떻게 구성되어 있는지(행, 열, 데이터 타입 등) 확인합니다.

# %%
# 전체적인 요약 정보 확인
print("--- 데이터 정보 ---")
df.info()

print("\n--- 데이터 크기 (행, 열) ---")
print(df.shape)

# %% [markdown]
# ### 1-4. 기초 통계량 확인하기
# 수치형 데이터의 평균, 표준편차, 사분위수 등을 한눈에 확인합니다.

# %%
df.describe()

# %% [markdown]
# ### 1-5. 결측치(Missing Value) 확인
# 데이터 중 비어 있는 값(NaN)이 어디에 얼마나 있는지 파악합니다.

# %%
# 각 열별 결측치 개수 합계
df.isnull().sum()

# %% [markdown]
# ---
# ## ✍️ 스스로 해보기 (Quiz)
# **문제: 'age' 열의 평균값(Mean)을 구해보세요.**

# %%
# 여기에 코드를 작성하세요
age_mean = 
print(f"나이 평균: {age_mean}")
